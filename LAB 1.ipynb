# %%
import numpy as np

# %%
arr=np.array([[1,2],[1,2]])
arr2=np.array([[1,2],[1,2]])

# %%
arr.sum()
# Out:
# 20

# %%
print(arr+arr2)
# Out:
# [[2 4 6 8]
#  [2 4 6 8]]

# %%
two_d = []

for i in range(len(arr)):
    one_d = [] 
    for j in range(len(arr[i])):
        a = arr[i][j] + arr2[i][j]  
        one_d.append(a)
    two_d.append(one_d)

# %%
print(two_d)
# Out:
# [[2, 4, 6, 8], [2, 4, 6, 8]]

# %%
two_d = []

for i in range(len(arr)):
    one_d = [] 
    for j in range(len(arr[i])):
        a = arr[i][j] * arr2[i][j]  
        one_d.append(a)
    two_d.append(one_d)

# %%
print(two_d)
# Out:
# [[1, 4, 9, 16], [1, 4, 9, 16]]

# %%
np.matmul(arr,arr2)
# Out:
# array([[3, 6],
#        [3, 6]])

# %%
arr=np.array([[1,2],[1,2]])
arr2=np.array([[1,2],[1,2]])

# %%
two_d=[]
for i in range(len(arr)):
    one_d=[]
    for j in range(len(arr2[0])):
        sum=0
        for k in range(len(arr[i])):
            sum =sum+ arr[i][k] * arr2[k][j]
            print(arr[i][k],'------------',arr2[k][j])
            print('-------',sum,'-------')
        one_d.append(sum)
        print('------',one_d,'------')
        
    two_d.append(one_d)
# Out:
# 1 ------------ 1
# ------- 1 -------
# 2 ------------ 1
# ------- 3 -------
# ------ [3] ------
# 1 ------------ 2
# ------- 2 -------
# 2 ------------ 2
# ------- 6 -------
# ------ [3, 6] ------
# 1 ------------ 1
# ------- 1 -------
# 2 ------------ 1
# ------- 3 -------
# ------ [3] ------
# 1 ------------ 2
# ------- 2 -------
# 2 ------------ 2
# ------- 6 -------
# ------ [3, 6] ------

# %%
print(two_d)
# Out:
# [[3, 6], [3, 6]]
